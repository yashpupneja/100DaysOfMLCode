# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (25, 12)
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('H:\SELF\Yashu\kpit_weather.csv')

# %%
data.head()
# Out:
#             ZTime            Time  OAT  DT    SLP   WD  WS  SKY  PPT  PPT6  \
# 0  20130101050000  20130101000000    0 -28  10180  250  46    8    3 -9999
# 1  20130101060000  20130101010000    0 -22  10175  260  31    8   -1 -9999
# 2  20130101070000  20130101020000   -6 -22  10175  260  41    8   -1 -9999
# 3  20130101080000  20130101030000   -6 -17  10175  240  21    8   -1 -9999
# 4  20130101090000  20130101040000   -6 -17  10173  250  26    8   -1 -9999
#
#   Plsr.Event Plsr.Source
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
data.shape
# Out:
# (43824, 12)

# %%
slp = data['SLP'].values
wd = data['WD'].values
ws = data['WS'].values

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(slp,wd,ws)
plt.show()

# %%
m = len(slp)
x0 = np.ones(m)
X = np.array([x0, slp, wd]).T
B = np.array([0, 0, 0])
Y = np.array(ws)
alpha = 0.0001

# %%
def cost_function(X, Y, B):
    m = len(Y)
    J = np.sum((X.dot(B) - Y) ** 2)/(2 * m)
    return J

# %%
cost_function(X, Y, B)
# Out:
# 29300.572140836073
